# %%
import networkx as nx
import matplotlib.pylab as pit
g=nx.read_edgelist("DANIYAL.txt")
print(nx.info(g))
nx.draw_circular(g)
pit.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 76
# Number of edges: 83
# Average degree:   2.1842

# %%
import networkx as nx
import matplotlib.pylab as pit
g=nx.read_edgelist("DANIYAL.txt")
print(nx.info(g))
nx.draw(g)
pit.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 76
# Number of edges: 83
# Average degree:   2.1842
